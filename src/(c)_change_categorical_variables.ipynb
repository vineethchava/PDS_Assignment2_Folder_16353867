# %%
import pandas as pd

# %%
clean_data = pd.read_csv('/content/data_clean/data_clean.csv')

# %%
processed_data = pd.get_dummies(clean_data, columns=['Fuel_Type', 'Transmission'])
processed_data.to_csv('/content/results/data_encoded.csv', index=False)

# %%
processed_data.head(40)
# Out:
#                                                 Name    Location  Year  \
# 0                   Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 1                                       Honda Jazz V     Chennai  2011
# 2                                  Maruti Ertiga VDI     Chennai  2012
# 3                    Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# 4                             Nissan Micra Diesel XV      Jaipur  2013
# 5                  Toyota Innova Crysta 2.8 GX AT 8S      Mumbai  2016
# 6                Volkswagen Vento Diesel Comfortline        Pune  2013
# 7                     Tata Indica Vista Quadrajet LS     Chennai  2012
# 8                                   Maruti Ciaz Zeta       Kochi  2018
# 9                        Honda City 1.5 V AT Sunroof     Kolkata  2012
# 10                             Maruti Swift VDI BSIV      Jaipur  2015
# 11                  Land Rover Range Rover 2.2L Pure       Delhi  2014
# ...
